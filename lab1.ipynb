# %% [markdown]
# <a href="https://colab.research.google.com/github/ipz223-zdo/NeuralNet/blob/main/lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Зчитати файл CSV в dataframe форматі

# %%
import pandas as pd

df = pd.read_csv('russia_losses_equipment.csv')
df
# Out:
#            date  day  aircraft  helicopter  tank    APC  field artillery  MRL  \
# 0    2022-02-25    2        10           7    80    516               49    4
# 1    2022-02-26    3        27          26   146    706               49    4
# 2    2022-02-27    4        27          26   150    706               50    4
# 3    2022-02-28    5        29          29   150    816               74   21
# 4    2022-03-01    6        29          29   198    846               77   24
# ..          ...  ...       ...         ...   ...    ...              ...  ...
# 726  2024-02-21  728       338         325  6516  12338             9826  992
# 727  2024-02-22  729       339         325  6523  12373             9867  997
# 728  2024-02-23  730       339         325  6526  12410             9916  999
# 729  2024-02-24  731       340         325  6534  12425             9952  999
# 730  2024-02-25  732       340         325  6542  12441             9981  999
#
# ...

# %% [markdown]
# Відфільтрувати dataframe по значенню певного параметру. (==);

# %%
df4 = df[df['drone'] == 2];
df4
# Out:
#          date  day  aircraft  helicopter  tank  APC  field artillery  MRL  \
# 1  2022-02-26    3        27          26   146  706               49    4
# 2  2022-02-27    4        27          26   150  706               50    4
#
#    military auto  fuel tank  drone  naval ship  anti-aircraft warfare  \
# 1          130.0       60.0      2           2                      0
# 2          130.0       60.0      2           2                      0
#
#    special equipment  mobile SRBM system greatest losses direction  \
# 1                NaN                 NaN                       NaN
# 2                NaN                 NaN                       NaN
#
#    vehicles and fuel tanks  cruise missiles  submarines
# 1                      NaN              NaN         NaN
# 2                      NaN              NaN         NaN

# %% [markdown]
# Відфільтрувати dataframe по значенню усі крім значення певного
# параметру. (!=)

# %%
df5 = df[df['aircraft'] != 27];
df5
# Out:
#            date  day  aircraft  helicopter  tank    APC  field artillery  MRL  \
# 0    2022-02-25    2        10           7    80    516               49    4
# 3    2022-02-28    5        29          29   150    816               74   21
# 4    2022-03-01    6        29          29   198    846               77   24
# 5    2022-03-02    7        30          31   211    862               85   40
# 6    2022-03-03    8        30          31   217    900               90   42
# ..          ...  ...       ...         ...   ...    ...              ...  ...
# 726  2024-02-21  728       338         325  6516  12338             9826  992
# 727  2024-02-22  729       339         325  6523  12373             9867  997
# 728  2024-02-23  730       339         325  6526  12410             9916  999
# 729  2024-02-24  731       340         325  6534  12425             9952  999
# 730  2024-02-25  732       340         325  6542  12441             9981  999
#
# ...

# %% [markdown]
# Відфільтрувати dataframe по значенню певного параметру, яке
# знаходиться в масиві. (isin)

# %%
values = [7, 29, 31]
df6 = df[df['helicopter'].isin(values)];
df6
# Out:
#          date  day  aircraft  helicopter  tank  APC  field artillery  MRL  \
# 0  2022-02-25    2        10           7    80  516               49    4
# 3  2022-02-28    5        29          29   150  816               74   21
# 4  2022-03-01    6        29          29   198  846               77   24
# 5  2022-03-02    7        30          31   211  862               85   40
# 6  2022-03-03    8        30          31   217  900               90   42
#
#    military auto  fuel tank  drone  naval ship  anti-aircraft warfare  \
# 0          100.0       60.0      0           2                      0
# 3          291.0       60.0      3           2                      5
# 4          305.0       60.0      3           2                      7
# 5          355.0       60.0      3           2                      9
# 6          374.0       60.0      3           2                     11
#
#    special equipment  mobile SRBM system greatest losses direction  \
# ...

# %% [markdown]
# Відфільтрувати dataframe по значенню <=, >=, <= & >=

# %%
df7 = df[(df['tank'] >= 149) & (df['tank'] <= 260)];
df7
# Out:
#          date  day  aircraft  helicopter  tank  APC  field artillery  MRL  \
# 2  2022-02-27    4        27          26   150  706               50    4
# 3  2022-02-28    5        29          29   150  816               74   21
# 4  2022-03-01    6        29          29   198  846               77   24
# 5  2022-03-02    7        30          31   211  862               85   40
# 6  2022-03-03    8        30          31   217  900               90   42
# 7  2022-03-04    9        33          37   251  939              105   50
#
#    military auto  fuel tank  drone  naval ship  anti-aircraft warfare  \
# 2          130.0       60.0      2           2                      0
# 3          291.0       60.0      3           2                      5
# 4          305.0       60.0      3           2                      7
# 5          355.0       60.0      3           2                      9
# 6          374.0       60.0      3           2                     11
# ...

# %% [markdown]
# Створити новий dataframe з певними колонками попередньо
# зчитаного dataframe, та зберегти в новий CSV файл

# %%
new_df = df[['date', 'tank']]
new_df.to_csv('new_file.csv', index=False)
new_df
# Out:
#            date  tank
# 0    2022-02-25    80
# 1    2022-02-26   146
# 2    2022-02-27   150
# 3    2022-02-28   150
# 4    2022-03-01   198
# ..          ...   ...
# 726  2024-02-21  6516
# 727  2024-02-22  6523
# 728  2024-02-23  6526
# 729  2024-02-24  6534
# 730  2024-02-25  6542
#
# [731 rows x 2 columns]

# %% [markdown]
# Згенерувати декілька колонок (2 або більше) даних використовуючи
# np.random.uniform та зберегти це в CSV використовуючи dataframe

# %%
import numpy as np
x = np.random.uniform(low = 0, high = 100, size=(1,50)).flatten()
y = np.random.uniform(low = 10, high = 20, size=(1,50)).flatten()
df = pd.DataFrame({"x": x, "y": y})
df.to_csv('task9.csv', index=False)
df
# Out:
#             x          y
# 0   28.383900  10.071948
# 1    0.996684  13.185687
# 2   27.141955  14.757593
# 3   62.006512  11.541305
# 4   60.039158  17.896781
# 5    5.183619  19.226942
# 6    1.937456  18.134350
# 7   50.258114  12.867349
# 8   33.427944  19.294856
# 9   19.047860  13.416206
# 10  32.759171  15.717488
# 11  99.130910  15.353598
# 12  80.032850  10.031677
# 13  66.262687  12.085848
# 14  82.224070  18.410454
# 15  62.010491  18.448189
# 16  96.856892  19.459961
# 17  78.700089  19.767350
# 18  91.373146  16.924037
# 19  17.945398  12.775802
# 20   9.609383  15.863555
# 21  48.213195  12.607040
# 22  20.359712  19.999511
# 23   2.113243  18.731128
# 24  62.333113  17.483493
# 25   0.787650  12.055860
# 26  74.462015  12.940817
# 27  30.235036  13.796176
# 28  73.929135  17.831323
# 29  18.057131  11.769490
# 30  98.746023  18.565939
# 31  66.647185  13.994891
# 32  13.024267  16.215072
# 33  25.682501  18.438543
# 34  17.757748  11.727219
# 35  94.147461  17.837694
# ...

# %% [markdown]
# Відобразити числові дані у вигляді лінійного графіку з CSV файлу,
# який Ви знайшли у завданні 1

# %%
import plotly.express as px
df = pd.read_csv('russia_losses_equipment.csv')
fig = px.line(df, x="date", y=["tank", 'aircraft', 'helicopter',	'APC',	'field artillery',	'MRL',	'drone',	'naval ship',	'anti-aircraft warfare'])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Відобразити числові дані у вигляді лінійного графіку з CSV файлу,
# який Ви знайшли у завданні 1, враховуючи фільтри реалізованів
# завданнях 4-7 (включно)

# %% [markdown]
# Графік для завдання 4:

# %%
fig = px.line(df4, x="date", y=["tank"])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Графік для завдання 5:

# %%
fig = px.line(df5, x="date", y=["aircraft"])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Графік для завдання 6:

# %%
fig = px.line(df6, x="date", y=["helicopter"])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Графік для завдання 7:

# %%
fig = px.line(df6, x="date", y=["tank"])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Знайти дані на Kaggle, або звернутися до викладача за наданням
# даних, і відобразити числові дані у форматі 3д зображення

# %%
df = pd.read_csv('iris.csv')
df
fig = px.scatter_3d(df, x='Sepal Length (cm)', y='Sepal Width (cm)', z='Petal Length (cm)',
                    color='Species')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Реалізувати просту нейронну мережу та навчити на даних наданих у
# файлі alarms.csvю Відобразити набір даних з файлу alarms.csv у форматі 3д
# зображення. Протестувати нейронну мережу

# %%
import pandas as pd
import numpy as np
import plotly.express as px
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras import layers, models

df = pd.read_csv('alarms.csv')
fig = px.scatter_3d(df, x ='sound', y='visibility', z='alarm')
#fig.show()

x = df[['sound', 'distance', 'visibility']].values
y = df[['alarm']].values

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

model = models.Sequential([
    layers.Dense(1, input_shape=(x_train.shape[1],), activation='sigmoid')
    ])

model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mse'])

model.fit(x_train, y_train, epochs=50, batch_size=32, validation_data=(x_test, y_test))

loss, accuracy = model.evaluate(x_test, y_test)
print("Test Loss:", loss)
print("Test Accuracy:", accuracy)
# Out:
# Epoch 1/50
# 25/25 [==============================] - 1s 10ms/step - loss: 0.1622 - mse: 0.1622 - val_loss: 0.1557 - val_mse: 0.1557
# Epoch 2/50
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1558 - mse: 0.1558 - val_loss: 0.1496 - val_mse: 0.1496
# Epoch 3/50
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1494 - mse: 0.1494 - val_loss: 0.1436 - val_mse: 0.1436
# Epoch 4/50
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1430 - mse: 0.1430 - val_loss: 0.1376 - val_mse: 0.1376
# Epoch 5/50
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1368 - mse: 0.1368 - val_loss: 0.1316 - val_mse: 0.1316
# Epoch 6/50
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1306 - mse: 0.1306 - val_loss: 0.1259 - val_mse: 0.1259
# Epoch 7/50
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1245 - mse: 0.1245 - val_loss: 0.1203 - val_mse: 0.1203
# Epoch 8/50
# ...

# %%
new_data = np.array([
    [0.7, 0.1, 0.7],
    [0.3, 0.7, 0.3],
    [0.4, 0.5, 0.3],
    [0.6, 0.5, 0.7],
    [0.9, 0.1, 0.9],
])
predictions = model.predict(new_data)
print("Predictions:")
print(predictions)
# Out:
# 1/1 [==============================] - 0s 106ms/step
# Predictions:
# [[0.54971075]
#  [0.43354017]
#  [0.44244406]
#  [0.5448357 ]
#  [0.61247057]]
